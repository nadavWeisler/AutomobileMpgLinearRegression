# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
automobile_df = pd.read_csv('automobile_df_processed.csv')
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 17   21.0          6         200.0        85.0    2587          16.0   52
# 283  24.5          4         151.0        88.0    2740          16.0   45
# 149  26.0          4          97.0        46.0    1950          21.0   49
# 95   18.0          8         307.0       130.0    3504          12.0   52
# 378  18.2          8         318.0       135.0    3830          15.2   43

# %%
from sklearn.model_selection import train_test_split

X = automobile_df[['horsepower']]
y = automobile_df['mpg']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize=True).fit(X_train, y_train)

# %%
print('Training Score:', linear_model.score(X_train, y_train))
# Out:
# Training Score: 0.6082888999396974

# %%
y_pred = linear_model.predict(X_test)

# %%
from sklearn.metrics import r2_score

print('Test score: ', r2_score(y_test, y_pred))
# Out:
# Test score:  0.5749956797293538

# %%
fig, ax = plt.subplots(figsize=(10, 6))

plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red')

plt.xlabel('Horsepower')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
X = automobile_df[['age']]
y = automobile_df['mpg']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
linear_model = LinearRegression(normalize=True).fit(X_train, y_train)

# %%
print('Training Score:', linear_model.score(X_train, y_train))
# Out:
# Training Score: 0.3471213475288406

# %%
y_pred = linear_model.predict(X_test)

# %%
print('Test score: ', r2_score(y_test, y_pred))
# Out:
# Test score:  0.22490982007770144

# %%
fig, ax = plt.subplots(figsize=(10, 6))

plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red')

plt.xlabel('Age')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
X = automobile_df[['displacement', 'horsepower', 'weight']]
y = automobile_df['mpg']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
linear_model = LinearRegression(normalize=True).fit(X_train, y_train)

# %%
print('Training Score:', linear_model.score(X_train, y_train))
# Out:
# Training Score: 0.6912428407504024

# %%
predictors = X_train.columns
coef = pd.Series(linear_model.coef_, predictors).sort_values()
coef
# Out:
# horsepower     -0.036381
# displacement   -0.009024
# weight         -0.005093
# dtype: float64

# %%
y_pred = linear_model.predict(X_test)

# %%
print('Test score: ', r2_score(y_test, y_pred))
# Out:
# Test score:  0.7652059044622684

# %%
plt.figure(figsize=(10, 6))

plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')

plt.ylabel('MPG')
plt.legend()
plt.show()
